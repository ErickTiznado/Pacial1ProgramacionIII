# %% [markdown]
# <a href="https://colab.research.google.com/github/ErickTiznado/Pacial1ProgramacionIII/blob/main/Ejercicio3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.  Desarrolle  el  conversor  de  Área  (Superficie)  haciendo  uso  de  los
# diccionarios  y  las  funciones  de  usuario  en  Python  que  contenga  las
# siguientes opciones: (20%)
#
# a.  Pie Cuadrado
#
# b.  Vara Cuadrada
#
# c.  Yarda Cuadrada
#
# d.  Metro Cuadrado
#
# e.  Tareas
#
# f.  Manzana
#
# g.  Hectárea

# %%
#1 Conversion de pies cuadrados a metros cuadrados

def PiesCuadrados_metrosCuadrados():
  piesCuadrados = int(input("Por favor, Ingrese la cantidad de pies cuadrados a convertir "))
  metrosCuadrados = piesCuadrados / 10.764
  print (piesCuadrados,"Pies cuadrados equivalen a ",metrosCuadrados,"metros cuadrados.")

#2 Conversion de metros cuadrados a hectareas

def metrosCuadrados_hectareas():
  metrosCuadrados = int(input("Por favor, Ingrese la cantidad de metros cuadrados a convertir "))
  hectareas = metrosCuadrados / 10000
  print (metrosCuadrados,"metrosCuadrados equivalen a ",hectareas,"hectareas.")

#3Conversion de metros cuadrados a pies cuadrados

def metrosCuadrados_PiesCuadrados():
  metrosCuadrados = int(input("Ingrese la cantidad de metros cuadrados a convertir "))
  PiesCuadrados = metrosCuadrados * 10.764
  print (metrosCuadrados,"metrosCuadrados equivalen a ",PiesCuadrados,"PiesCuadrados.")

#4 Conversion de yardas cuadradas a pies cuadrados

def YardasCuadrados_PiesCuadrados():
  YardasCuadrados = int(input("Ingrese la cantidad de yardas cuadradas a convertir "))
  PiesCuadrados = YardasCuadrados * 9
  print (YardasCuadrados,"yardas cuadradas equivalen a ",PiesCuadrados,"pies cuadrados.")

#5 Hectareas a yardas cuadrados

def hectareas_YardasCuadrados():
  hectareas = int(input("Ingrese la cantidad de hectareas a convertir "))
  YardasCuadrados = hectareas * 11960
  print (hectareas,"hectareas equivalen a ",YardasCuadrados,"yardasCuadradas.")

#6 Manzanas a varas cuadradas

def manzanas_varasCuadradas():
  manzanas = int(input("Ingrese la cantidad de manzanas a convertir "))
  varasCuadradas = manzanas * 0.84
  print (manzanas,"manzanas equivalen a ",varasCuadradas,"yardasCuadradas.")

#7 Conversion de tareas a metros cuadrados 

def tarea_metroCuadrado():
  tarea = int(input("Ingrese la cantidad de tareas a convertir "))
  metroCuadrado = tarea * 628.86
  print (tarea,"tareas equivalen a ",metroCuadrado,"metrosCuadrados.")

#8 Metros cuadrados a varas cuadradas

def metrosCuadrados_varasCuadradas():
  metrosCuadrados = int(input("Ingrese la cantidad de metros cuadrados a convertir "))
  varasCuadradas = metrosCuadrados / 0.7
  print (metrosCuadrados,"metrosCuadrados equivalen a ",varasCuadradas,"yardasCuadradas.")

#9  Tarea a hectarea

def tarea_hectarea():
  tarea = int(input("Ingrese la cantidad de tareas a convertir "))
  hectareas = tarea * 0.06288
  print (tarea,"tareas equivalen a ",hectareas,"hectareas.")

#10 Tarea a Manzana

def tarea_manzana():
  tarea = int(input("Ingrese la cantidad de tareas a convertir "))
  manzana= tarea * 0.06288
  print (tarea,"tareas equivalen a ",manzana,"manzanas.")

#11 Metros cuadrados a Yarda Cuadrada

def metrosCuadrados_yardaCuadrada():
  metrosCuadrados = int(input("Ingrese la cantidad de metros cuadrados a convertir "))
  yardasCuadradas= metrosCuadrados / 0.8361
  print (metrosCuadrados,"metros cuadrados equivalen a ",yardasCuadradas,"yardas cuadradas.")

#12 Yardas Cuadradas a Metros Cuadrados

def yardasCuadradas_metrosCuadrados():
  yardasCuadradas = int(input("Ingrese la cantidad de metros cuadrados a convertir "))
  metrosCuadrados= yardasCuadradas * 0.8361
  print (yardasCuadradas,"Yardas cuadradas equivalen a ",metrosCuadrados,"Metros cuadrados.")

#13 Pies cuadrados a Yarda Cuadrada

def piesCuadrados_yardaCuadrada():
  piesCuadrados = int(input("Ingrese la cantidad de metros cuadrados a convertir "))
  yardasCuadradas= piesCuadrados * 0.111
  print (piesCuadrados,"metros cuadrados equivalen a ",yardasCuadradas,"yardas cuadradas.")

  
#14 Yardas Cuadradas a Pies Cuadrados

def yardasCuadradas_PiesCuadrados():
  yardasCuadradas = int(input("Ingrese la cantidad de metros cuadrados a convertir "))
  PiesCuadrados= yardasCuadradas / 0.111
  print (yardasCuadradas,"Yardas cuadradas equivalen a ",PiesCuadrados,"Metros cuadrados.")



opcionSeleccionada = int( input("\n**MENU DE CONVERSIONES**\n\n"
                    "1. Pies cuadrados a Metros cuadrados \n"
                    "2. Metros cuadrados a Hectareas \n"
                    "3. Metros cuadrados a Pies cuadrados \n"
                    "4. Yardas cuadrados a Pies cuadrados \n"
                    "5. Hectareas a Yardas cuadrados \n"
                    "6. Manzanas a Varas cuadrados\n"
                    "7. Tareas a Metros cuadrados \n"
                    "8. Metros cuadrados a Varas cuadradas \n"
                    "9. Tareas a Hectareas \n"
                    "10. Tareas a Manzanas \n"
                    "11. Metros cuadrados a Yarda Cuadrada \n"
                    "12.  Yardas Cuadradas a Metros Cuadrados \n"
                    "13. Pies cuadrados a Yarda Cuadrada \n"
                    "14.  Yardas Cuadradas a Pies Cuadrados \n"
                    "Por favor, Ingrese al opcion que desea \n\n"))

opcionesConversion = {1:PiesCuadrados_metrosCuadrados,
               2:metrosCuadrados_hectareas,
               3:metrosCuadrados_PiesCuadrados,
               4:YardasCuadrados_PiesCuadrados,
               5:hectareas_YardasCuadrados,
               6:manzanas_varasCuadradas,
               7:tarea_metroCuadrado,
               8:metrosCuadrados_varasCuadradas,
               9:tarea_hectarea,
               10:tarea_manzana,
               11:metrosCuadrados_yardaCuadrada,
               12:yardasCuadradas_metrosCuadrados,
               13:piesCuadrados_yardaCuadrada,
               14:yardasCuadradas_PiesCuadrados}



try:
  opcionesConversion[opcionSeleccionada]()
except:
  print("La opcion que usted ha seleccionado no es valida, por seleccione otra")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-f2d46791f5ff> in <module>
#     100
#     101
# --> 102 opcionSeleccionada = int( input("\n**MENU DE CONVERSIONES**\n\n"
#     103                     "1. Pies cuadrados a Metros cuadrados \n"
#     104                     "2. Metros cuadrados a Hectareas \n"
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
